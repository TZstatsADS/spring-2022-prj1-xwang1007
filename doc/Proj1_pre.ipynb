# %% [markdown]
# # What Were Philosophers from Different Times Talking about?

# %% [markdown]
# # Project 1_Xinran Wang

# %% [markdown]
# **General Introduction to Project 1**
#
# The dataset, philosophy, was compiled for the Philosophy Data Project and posted on Kaggle. To be honest, as a Stats student, I have little professional knowledge related to Philosophy. If I have ever been involved in any Philosophical knowledge, it was probably that I have read some books from popular Socrates, Hegel, but overall I am a layman. However, when I first saw this dataset as a Stats student, I was really curious about what philosophers from different times were talking about since there were so many different sentences from various philosophers and times. To make this general question more specific, I divided them into the following three questions:
#
# **Question 1**<br>
# How has the vocabulary often used by philosophers changed over time？<br>
# **Question 2**<br>
# Were ancient philosophers more pessimistic than modern philosophers?<br>
# **Question 3**<br>
# What were the most popular Philosophical topics in different times?<br>
#
# To solve these three questions, I respectively used methods of Word Cloud, Sentiment Analysis, and latent Dirichlet allocation (LDA) to analyze the questions and visualize the results, which I will explain one by one later. The whole project, as a result, is divided into three parts. On the other hand, for presentation purposes, I divided the text into 3 periods based on the date of the document: BC 350 ~ 170(ancient), 1673 ~ 1798(medieval), and 1807 ~ 1985(modern).

# %% [markdown]
# ## Part 1 Word Cloud

# %% [markdown]
# Before further exploring the data, I examined and pre-processed the dataset in three aspects(the first for check and the next two for pre-processing):
# * Print the dataset and describe it in general;
# * Check if there exist any null values;
# * Remove stop words such as 'the', 'for', 'be', and so on.
#
# Through checking, I found that there is no missing value. So, I just continued to import **nltk.corpus** package to remove the stop words, which are kind of meaningless to the questions.

# %% [markdown]
# ![des.png](attachment:des.png)

# %% [markdown]
# For the **first question**, how the vocabulary often used by philosophers changed over three periods, I decided to use Word Cloud. Intuitively, the more times a word appears in text resources, the larger and bolder it becomes in the word cloud, and it may be more important.
#
# The following three figures respectively represent word clouds from three periods, namely, ancient, medieval and modern. We can observe some association between word clouds and events or thought during that period.
#
# From the first picture, we can see words such as 'epic', 'indicted', and 'effect' were most important, while 'socrates', 'athenians', and 'prosecuting' were also mentioned a lot. The result makes sense because Socrates is known for his quest for truth, and for Apology of Socrates, which was compiled and written by his student Plato.
#
# The second picture showed that the most frequent words have changed to 'women', 'rights', and 'hope', which indicated that philosophers from the middle age shifted their interest to humans. Some famous sentences, such as I think, therefore I am, nicely supported this change.
#
# The third-word cloud gave us some information that the modern philosophers began to refer to words like 'psychologists', 'sychology', and 'physicists'. With the development of psychology, modern philosophers have also kept up with the times and combined their doctrines with it.

# %% [markdown]
# ![wordc.png](attachment:wordc.png)

# %% [markdown]
# ## Part 2 Sentiment Analysis

# %% [markdown]
# To start with sentiment analysis, I built a Bi-directional LSTM multi-label sentiment classification model. The model was trained using the semeval2018 dataset. Applying the trained model on cleaned Twitter data for each month, I created a sentiment evolving graph for the three periods.
#
# The flow chart provided information on the Bi-directional LSTM Architecture. I employed the GloVe (Global Vectors for Word Representation) at the embedding layer to generate an embedding matrix for the input texts. Then I made a bi-directional LSTM layer with 128 units each. Finally, I used the Sigmoid activation function to produce multi-label outputs. The model produces a multi-label accuracy of 67% and an F1-micro score of 0.57, which I think is pretty great.

# %% [markdown]
# ![LSTM%20model.png](attachment:LSTM%20model.png)

# %% [markdown]
# For **question 2**, were ancient philosophers more pessimistic than modern philosophers, the sentiment analysis would be of great help. I defined the sentiment rate (for each sentiment of three periods) to be the ratio of the total number of sentences with that sentiment to all sentences of the period.
#
# The line graph gave us the answer to question 2 to some degree, that is, philosophers from the middle age were the most pessimistic.
# They felt more disgusting, fearful, and sad than the other two groups. In addition, ancient philosophers were more pessimistic than modern philosophers.

# %% [markdown]
# ![sentline.png](attachment:sentline.png)

# %% [markdown]
# In order to have a more intuitive look at the positive and negative emotions of philosophers in different periods, on the basis of the line graph, I created a bar graph. As depicted in the bar chart, when I divided the eleven feelings into two groups: (anticipation, joy, love, optimism, and trust) and negative (anger, disgust, fear, pessimism, and sadness), we can see that Philosophers expressed more negative emotions than good emotions during all times, which I think was in line with the sad undertones of philosophy. In general, the total rate of negative emotions is around double that of positive emotions.

# %% [markdown]
# ![sentibar.png](attachment:sentibar.png)

# %% [markdown]
# ## Part 3 LDA

# %% [markdown]
# For **question 3**, what were the most popular Philosophical topics in different times? To discover the topics, I used Latent Dirichlet Allocation (LDA) algorithm. First, I used the LDA Mallet model with a range of total topic number values on all phrases in each theme. The model with the highest coherence score was picked as the best model. The best value for the number of subjects is the total topic number. Then, using this ideal topic number, I recreated an LDA Mallet model. Finally, I used PyLDAVis, a visualization tool, to show the topic modeling results in order to have a better and more intuitive grasp of the topic modeling results.

# %% [markdown]
# Now I applied the LDA Mallet model and created 2 topics.
#
# The following figure showed the word cloud for each topic during the first period. For the first topic, words such as 'desire', 'acknowledge' could be meaningful because Socrates liked to ask questions about abstract things. However, to my surprise, 'traffic' and 'things' were the most obvious words. So I referred to the csv file to see if I could find anything related. From my point of view, these words, especially 'traffic' were like idioms. The other topics was more focused on 'information', 'feeling', 'events', which were real vocabulary.

# %% [markdown]
# ![LDA1.png](attachment:LDA1.png)

# %%
from IPython.display import IFrame

IFrame(src='./lda_period1.html', width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="./lda_period1.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# The second graph represented topics of the middle age. 'Mind' is the most outstanding word within the first topic. I also found that words such as 'observation' and 'physical'(from the other topic) were interesting, which, in my opinion, may indicate the beginning of the association between philosophy and science.

# %% [markdown]
# ![LDA2.png](attachment:LDA2.png)

# %%
from IPython.display import IFrame

IFrame(src='./lda_period2.html', width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="./lda_period2.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# The LDA graph of period 3 was really huge. The result of optimization of LDA indicated that the more numbers of topics, the better. But after 16, there was little variety, so I just picked 16 topics. And we can see from the word clouds that high-frequency words becoming richer and richer, around topics such as humans, nature, work, and so on. Also, words such as 'logic', 'theory', and 'truth' may be related to the development of modern technology, while words 'labor', 'time', and 'capital' indicated the development of Marxism.

# %% [markdown]
# ![LDA3-1.png](attachment:LDA3-1.png)
# ![LDA3-2.png](attachment:LDA3-2.png)

# %%
from IPython.display import IFrame

IFrame(src='./lda_period3.html', width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./lda_period3.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Conclusion

# %% [markdown]
# In general, the whole research process was really fun. On one hand, technically speaking, this study of mine mainly uses Word Clouds, Sentiment Analysis, and LDA. On the other hand, my visualization tools answered the question, also the title **what were philosophers talking about from different times** to a certain degree. In the past, when western Philosophy began, Socrates could be one of the representatives. They were more interested in proposing questions to make people understand the world. Then, in the middle age, with the development of technology, philosophers tried to connect themselves with philosophy and focused on human rights. Finally, modern philosophers think more about the development of humans and society.
